# %%
from statistics_Y_plot import statistics_Y_plot
import numpy as np

# Initialize the class
stat_plot = statistics_Y_plot(alpha=0.05)

# Example data
data1 = [1.2, 2.3, 3.1, 4.0]
data2 = [1.5, 2.1, 2.9, 3.8]

# One-way repeated-measure ANOVA
anova_table, posthoc_df = stat_plot.one_factor_rm_anova(data1, data2, factor_name='Condition')

# Plot
stat_plot.plot_with_scatter([data1, data2], xticklabels=['Cond1','Cond2'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 import numpy as np
#       4 # Initialize the class
# ----> 5 stat_plot = statistics_Y_plot(alpha=0.05)
#       7 # Example data
#       8 data1 = [1.2, 2.3, 3.1, 4.0]
#
# TypeError: 'module' object is not callable

# %%
import statistics_Y_plot
print(dir(statistics_Y_plot))  # 查看类是否存在
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'statistics_Y_plot']
